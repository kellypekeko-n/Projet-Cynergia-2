# %%
import pandas as pd

# Remplace le nom du fichier par le chemin exact de ton dataset s'il est différent
df = pd.read_csv("Dataset.csv")

# Cette ligne permet d'afficher les 5 premières lignes sous forme de beau tableau
df.head()
# Out:
#        sAddress      rAddress              sMACs              rMACs  \
# 0  192.168.0.11  192.168.0.21  02:42:c0:a8:00:0b  02:42:c0:a8:00:15
# 1  192.168.0.12  192.168.0.21  02:42:c0:a8:00:0c  02:42:c0:a8:00:15
# 2  192.168.0.11  192.168.0.12  02:42:c0:a8:00:0b  02:42:c0:a8:00:0c
# 3  192.168.0.11  192.168.0.12  02:42:c0:a8:00:0b  02:42:c0:a8:00:0c
# 4  192.168.0.11  192.168.0.21  02:42:c0:a8:00:0b  02:42:c0:a8:00:15
#
#            sIPs          rIPs  protocol                   startDate  \
# 0  192.168.0.11  192.168.0.21  IPV4-TCP  2022-09-16 11:14:39.510337
# 1  192.168.0.12  192.168.0.21  IPV4-TCP  2022-09-16 11:14:39.513421
# 2  192.168.0.11  192.168.0.12  IPV4-TCP  2022-09-16 11:14:39.601160
# 3  192.168.0.11  192.168.0.12  IPV4-TCP  2022-09-16 11:14:40.200719
# 4  192.168.0.11  192.168.0.21  IPV4-TCP  2022-09-16 11:14:40.010348
#
#                       endDate         start  ...  sAckDelayMax  rAckDelayMax  \
# ...

# %%
# Afficher la liste de toutes les colonnes du dataset
print(df.columns.tolist())
# Out:
# ['sAddress', 'rAddress', 'sMACs', 'rMACs', 'sIPs', 'rIPs', 'protocol', 'startDate', 'endDate', 'start', 'end', 'startOffset', 'endOffset', 'duration', 'sPackets', 'rPackets', 'sBytesSum', 'rBytesSum', 'sBytesMax', 'rBytesMax', 'sBytesMin', 'rBytesMin', 'sBytesAvg', 'rBytesAvg', 'sLoad', 'rLoad', 'sPayloadSum', 'rPayloadSum', 'sPayloadMax', 'rPayloadMax', 'sPayloadMin', 'rPayloadMin', 'sPayloadAvg', 'rPayloadAvg', 'sInterPacketAvg', 'rInterPacketAvg', 'sttl', 'rttl', 'sAckRate', 'rAckRate', 'sUrgRate', 'rUrgRate', 'sFinRate', 'rFinRate', 'sPshRate', 'rPshRate', 'sSynRate', 'rSynRate', 'sRstRate', 'rRstRate', 'sWinTCP', 'rWinTCP', 'sFragmentRate', 'rFragmentRate', 'sAckDelayMax', 'rAckDelayMax', 'sAckDelayMin', 'rAckDelayMin', 'sAckDelayAvg', 'rAckDelayAvg', 'IT_B_Label', 'IT_M_Label', 'NST_B_Label', 'NST_M_Label']

# %%
# Compter le nombre de lignes pour chaque type de trafic/attaque
print(df['NST_M_Label'].value_counts())
# Out:
# NST_M_Label
# Normal       36706
# mitm          2584
# replay        2358
# port-scan     1944
# ddos          1934
# ip-scan        192
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# 1. Initialiser le modèle Random Forest
# n_estimators=100 signifie que l'IA va construire une forêt de 100 arbres de décision
print("Initialisation du modèle Random Forest...")
model_rf = RandomForestClassifier(n_estimators=100, random_state=42)

# 2. Entraîner le modèle sur nos données d'entraînement
print("Entraînement en cours (l'IA analyse les patterns)...")
model_rf.fit(X_train, y_train)
print("Entraînement terminé !")

# 3. Demander à l'IA de prédire les attaques sur les données de test qu'elle n'a jamais vues
y_pred = model_rf.predict(X_test)

# 4. Afficher les performances globales et détaillées par attaque
print("\n=== RÉSULTATS DU MODÈLE RANDOM FOREST ===")
print(f"Précision globale (Accuracy) : {accuracy_score(y_test, y_pred) * 100:.2f}%\n")

# Le rapport va nous donner la précision pour chaque attaque (0, 1, 2, 3...)
print("Rapport détaillé des performances :")
print(classification_report(y_test, y_pred, target_names=encoder.classes_))
# Out:
# Initialisation du modèle Random Forest...
# Entraînement en cours (l'IA analyse les patterns)...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 11
#       9 # 2. Entraîner le modèle sur nos données d'entraînement
#      10 print("Entraînement en cours (l'IA analyse les patterns)...")
# ---> 11 model_rf.fit(X_train, y_train)
#      12 print("Entraînement terminé !")
#      14 # 3. Demander à l'IA de prédire les attaques sur les données de test qu'elle n'a jamais vues
#
# NameError: name 'X_train' is not defined

# %%
# Afficher la liste de toutes les colonnes du dataset
print(df.columns.tolist())
# Out:
# ['sAddress', 'rAddress', 'sMACs', 'rMACs', 'sIPs', 'rIPs', 'protocol', 'startDate', 'endDate', 'start', 'end', 'startOffset', 'endOffset', 'duration', 'sPackets', 'rPackets', 'sBytesSum', 'rBytesSum', 'sBytesMax', 'rBytesMax', 'sBytesMin', 'rBytesMin', 'sBytesAvg', 'rBytesAvg', 'sLoad', 'rLoad', 'sPayloadSum', 'rPayloadSum', 'sPayloadMax', 'rPayloadMax', 'sPayloadMin', 'rPayloadMin', 'sPayloadAvg', 'rPayloadAvg', 'sInterPacketAvg', 'rInterPacketAvg', 'sttl', 'rttl', 'sAckRate', 'rAckRate', 'sUrgRate', 'rUrgRate', 'sFinRate', 'rFinRate', 'sPshRate', 'rPshRate', 'sSynRate', 'rSynRate', 'sRstRate', 'rRstRate', 'sWinTCP', 'rWinTCP', 'sFragmentRate', 'rFragmentRate', 'sAckDelayMax', 'rAckDelayMax', 'sAckDelayMin', 'rAckDelayMin', 'sAckDelayAvg', 'rAckDelayAvg', 'IT_B_Label', 'IT_M_Label', 'NST_B_Label', 'NST_M_Label']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# 1. Initialiser le modèle Random Forest
# n_estimators=100 signifie que l'IA va construire une forêt de 100 arbres de décision
print("Initialisation du modèle Random Forest...")
model_rf = RandomForestClassifier(n_estimators=100, random_state=42)

# 2. Entraîner le modèle sur nos données d'entraînement
print("Entraînement en cours (l'IA analyse les patterns)...")
model_rf.fit(X_train, y_train)
print("Entraînement terminé !")

# 3. Demander à l'IA de prédire les attaques sur les données de test qu'elle n'a jamais vues
y_pred = model_rf.predict(X_test)

# 4. Afficher les performances globales et détaillées par attaque
print("\n=== RÉSULTATS DU MODÈLE RANDOM FOREST ===")
print(f"Précision globale (Accuracy) : {accuracy_score(y_test, y_pred) * 100:.2f}%\n")

# Le rapport va nous donner la précision pour chaque attaque (0, 1, 2, 3...)
print("Rapport détaillé des performances :")
print(classification_report(y_test, y_pred, target_names=encoder.classes_))
# Out:
# Initialisation du modèle Random Forest...
# Entraînement en cours (l'IA analyse les patterns)...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 11
#       9 # 2. Entraîner le modèle sur nos données d'entraînement
#      10 print("Entraînement en cours (l'IA analyse les patterns)...")
# ---> 11 model_rf.fit(X_train, y_train)
#      12 print("Entraînement terminé !")
#      14 # 3. Demander à l'IA de prédire les attaques sur les données de test qu'elle n'a jamais vues
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report

# --- 1. INITIALISATION DES ALGORITHMES ---
print("Initialisation des 3 algorithmes d'IA...")
models = {
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "XGBoost": XGBClassifier(n_estimators=100, random_state=42, eval_metric='logloss'),
    "Réseau de Neurones (MLP)": MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=200, random_state=42)
}

# --- 2. ENTRAÎNEMENT ET PRÉDICTION ---
results = {}

for name, model in models.items():
    print(f"\n--- Entraînement du modèle : {name} ---")
    model.fit(X_train, y_train)
    
    print(f"Évaluation de : {name}...")
    y_pred = model.predict(X_test)
    
    # Stockage des prédictions et scores
    results[name] = {
        "accuracy": accuracy_score(y_test, y_pred),
        "report": classification_report(y_test, y_pred, target_names=encoder.classes_, output_dict=True)
    }
    print(f"-> Terminé ! Précision globale : {results[name]['accuracy']*100:.2f}%")

print("\n=== [SUCCÈS] L'ENTRAÎNEMENT COMPARATIF EST TERMINÉ ! ===")
